# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\jimmy\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\jimmy\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic_clase4.csv")
titanic
# Out:
#              nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion  \
# 0       Jack Dawson           0      3    male  20.0    7.25           S
# 1       Rose DeWitt           1      1  female  17.0  512.33           C
# 2        John Smith           0      2    male  35.0   13.00           S
# 3      Mary Johnson           1      1  female  28.0   76.29           C
# 4      Thomas Brown           0      3    male   NaN    8.05           S
# 5   Elisabeth Jones           1      1  female  45.0   35.50           S
# 6     William Davis           0      3    male  23.0    7.92           Q
# 7      Sarah Wilson           1      2  female  31.0   21.00           S
# 8      James Miller           0      3    male   NaN    7.75           Q
# 9        Emma Moore           1      1  female  22.0  151.55           S
# 10    Robert Taylor           1      1    male  42.0   52.00           S
# 11    Anna Anderson           1      3  female  26.0    7.92           S
# 12  Charles Jackson           0      3    male  19.0    8.05           S
# 13   Margaret White           1      1  female  55.0   59.40           C
# 14    George Harris           0      3    male  29.0    7.25           S
# 15     Helen Martin           1      2  female  38.0   23.00           S
# 16  Edward Thompson           0      3    male   NaN    7.55           Q
# 17   Clara Robinson           1      1  female  33.0   83.15           C
# 18      Frank Lewis           0      3    male  40.0    9.50           S
# 19   Dorothy Walker           0      3  female  24.0    7.75           Q
# 20      Arthur Hall           0      3    male  36.0    7.25           S
# 21   Florence Allen           1      1  female  29.0  211.34           C
# 22      Henry Young           1      1    male  47.0   71.00           S
# 23    Beatrice King           1      3  female  21.0    8.43           S
# 24    Joseph Wright           0      3    male  33.0    7.92           Q
# 25      Mabel Scott           1      1  female  62.0   26.55           S
# 26     Walter Green           0      3    male   NaN    7.25           S
# 27      Alice Baker           1      2  female  27.0   21.00           C
# 28     Ernest Adams           0      3    male  44.0    8.05           S
# 29     Ethel Nelson           1      1  female  36.0  135.63           C
# 30       John Smith           0      2    male  35.0   13.00           S
#
#    cabina
# 0     NaN
# 1     B57
# 2     NaN
# 3     C85
# 4     NaN
# 5    C103
# 6     NaN
# 7     NaN
# 8     NaN
# 9     B45
# 10    C22
# 11    NaN
# 12    NaN
# 13    C68
# 14    NaN
# 15    NaN
# 16    NaN
# 17    E46
# 18    NaN
# 19    NaN
# 20    NaN
# 21    B30
# 22    C90
# 23    NaN
# 24    NaN
# 25   C101
# 26    NaN
# 27    NaN
# 28    NaN
# 29    B77
# 30    NaN

# %%
titanic_nuevo = titanic.drop(columns=["cabina"])
titanic_nuevo = titanic_nuevo.drop_duplicates()
media_edad = titanic_nuevo["edad"].median()
#titanic_nuevo["edad"] =
titanic_nuevo["edad"].fillna(media_edad)

print(f"info limpia: {titanic_nuevo.shape}")
# Out:
# info limpia: (30, 7)

# %%
tasa = titanic_nuevo["sobrevivio"].mean()
print(tasa)
print(f"Tasa de superviviencia: {tasa:.0%}")
# Out:
# 0.5333333333333333
# Tasa de superviviencia: 53%

# %%
titanic_nuevo.groupby("sexo")["sobrevivio"].mean()
# Out:
# sexo
# female    0.933333
# male      0.133333
# Name: sobrevivio, dtype: float64

# %%
titanic_nuevo.groupby("clase")["sobrevivio"].mean()
# Out:
# clase
# 1    1.000000
# 2    0.750000
# 3    0.133333
# Name: sobrevivio, dtype: float64

# %%
titanic_nuevo.groupby("edad")["sobrevivio"].mean()
# Out:
# edad
# 17.0    1.0
# 19.0    0.0
# 20.0    0.0
# 21.0    1.0
# 22.0    1.0
# 23.0    0.0
# 24.0    0.0
# 26.0    1.0
# 27.0    1.0
# 28.0    1.0
# 29.0    0.5
# 31.0    1.0
# 33.0    0.5
# 35.0    0.0
# 36.0    0.5
# 38.0    1.0
# 40.0    0.0
# 42.0    1.0
# 44.0    0.0
# 45.0    1.0
# 47.0    1.0
# 55.0    1.0
# 62.0    1.0
# Name: sobrevivio, dtype: float64

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jimmy\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jimmy\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\jimmy\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\jimmy\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grafico

# %%
supervivencia_sexo = titanic_nuevo.groupby("sexo")["sobrevivio"].mean()

plt.figure(figsize=(7,5))
supervivencia_sexo.plot(
    kind="bar",
    color=["#DB7E47","#245FC4"],
    edgecolor="white",
    width=0.5
)
# Out:
# <Axes: xlabel='sexo'>

# %%
supervivencia_clase = titanic_nuevo.groupby("clase")["sobrevivio"].mean()

plt.figure(figsize=(7,5))
supervivencia_clase.plot(
    kind="bar",
    color=["#DB7E47","#245FC4"],
    edgecolor="white",
    width=0.5
)
# Out:
# <Axes: xlabel='clase'>
